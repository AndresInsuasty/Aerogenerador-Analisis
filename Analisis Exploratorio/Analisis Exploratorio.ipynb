# %% [markdown]
# ## Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
path = '/content/drive/My Drive/'
file = 'SCADA_data_WT2337.csv'

# %%
data = pd.read_csv(path+file)
data.head()
# Out:
#         id  ld_id              date_time  ...  YawSdev  YawMin  YawMax
# 0  8322946   2337  2013-01-01 00:00:00.0  ...      NaN     NaN     NaN
# 1  8322947   2337  2013-01-01 00:10:00.0  ...      NaN     NaN     NaN
# 2  8322948   2337  2013-01-01 00:20:00.0  ...      NaN     NaN     NaN
# 3  8322949   2337  2013-01-01 00:30:00.0  ...      NaN     NaN     NaN
# 4  8322950   2337  2013-01-01 00:40:00.0  ...      NaN     NaN     NaN
#
# [5 rows x 177 columns]

# %%
data.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358134 entries, 0 to 358133
# Data columns (total 177 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          358134 non-null  int64
#  1   ld_id                       358134 non-null  int64
#  2   date_time                   358134 non-null  object
#  3   fake_data                   358134 non-null  int64
#  4   NumSampleTenMinBin          358134 non-null  int64
#  5   AcumGralPala1Mean           342735 non-null  float64
#  6   AcumGralPala1Sdev           342735 non-null  float64
#  7   AcumGralPala1Min            342738 non-null  float64
#  8   AcumGralPala1Max            342738 non-null  float64
#  9   AcumGralPala2Mean           342403 non-null  float64
#  10  AcumGralPala2Sdev           342403 non-null  float64
#  11  AcumGralPala2Min            342403 non-null  float64
# ...

# %%
data.describe()
# Out:
#                  id     ld_id  ...         YawMin         YawMax
# count  3.581340e+05  358134.0  ...  341569.000000  341569.000000
# mean   5.027944e+06    2337.0  ...     201.241725     212.067569
# std    2.928478e+06       0.0  ...      75.294856      74.102808
# min    2.560000e+02    2337.0  ...    -360.000000     -79.470000
# 25%    2.471570e+06    2337.0  ...     148.000000     154.000000
# 50%    5.031226e+06    2337.0  ...     229.000000     234.000000
# 75%    7.551866e+06    2337.0  ...     248.304000     258.000000
# max    1.011268e+07    2337.0  ...     360.000000     360.000000
#
# [8 rows x 176 columns]

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

data_na = data.isna().sum()
print('*'*50)
print('Total of data',data.shape[0])
print('*'*50)
print('Number of NaN values')
print('*'*50)
print_full(data_na)
# Out:
# **************************************************
# Total of data 358134
# **************************************************
# Number of NaN values
# **************************************************
# id                                 0
# ld_id                              0
# date_time                          0
# fake_data                          0
# NumSampleTenMinBin                 0
# AcumGralPala1Mean              15399
# AcumGralPala1Sdev              15399
# AcumGralPala1Min               15396
# AcumGralPala1Max               15396
# AcumGralPala2Mean              15731
# AcumGralPala2Sdev              15731
# AcumGralPala2Min               15731
# AcumGralPala2Max               15731
# AcumGralPala3Mean              15804
# AcumGralPala3Sdev              15806
# AcumGralPala3Min               15804
# AcumGralPala3Max               15804
# AutopilotoCalc                  2016
# CmdWTGMean                    314358
# CmdWTGSdev                    314358
# ...

# %%
data[['fake_data','AcumGralPala1Mean','CmdWTGMean','ConfirmContractGiroCCWMean','ContEnerActivaMean', 'CosPhiMean','Diag1_R4Mean','FrecRedMean','IndTurbulMean','NivOscilMean','NivVibraMean','Pitch1Mean',
      'Pitch2Mean','Pitch3Mean','PotMean','PresAcumGralMean','PresFrenoMean','PresGHMean','SPCosPhiMean','SPPitchMean','TempAceiteGHMean','TempAceiteMultipMean','TempAmbMean','TempCojLAMean','TempCojLOAMean',
      'TempGenMean','TempGondMean','TempRadInfMean','TempRadSupMean','TempRodamMultipMean','TempRodamTraseroMean','TempTrafo1Mean','TempTrafo2Mean','TempTrafo3Mean','TensRedMean','TotPotReactMean','VelGenMean',
      'VelRotorMean','VelVientoMean','YawMean']].hist(figsize = (20,20))
plt.tight_layout()

# %%
from pandas.plotting import scatter_matrix
p=scatter_matrix(data[['VelRotorMean','VelVientoMean','TempGenMean','TempGondMean','TempRadInfMean','TempRadSupMean','TempRodamMultipMean','TempRodamTraseroMean','TempTrafo1Mean','TempTrafo2Mean','TempTrafo3Mean','TensRedMean','TotPotReactMean','VelGenMean']],figsize=(25, 25))
plt.tight_layout()
